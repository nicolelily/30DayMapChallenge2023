# %%
import numpy as np
import pandas as pd
import folium
import requests

# %%
df = pd.read_csv('/work/Pleasantrees locations - locations.csv')

# %%
df.head()
# Out:
#             Name                   Street          City State    ZIP  \
# 0   East Lansing          1950 Merritt Rd  East Lansing    MI  48823
# 1     Mt Clemens   237 N River Rd Suite 2    Mt Clemens    MI  48043
# 2      Hamtramck        2238 Holbrook Ave     Hamtramck    MI  48212
# 3   Lincoln Park   1504 John A Papalas Dr  Lincoln Park    MI  48146
# 4  Houghton Lake  2161 W Houghton Lake DR   Prudenville    MI  48651
#
#     Latitude  Longitude
# 0  42.747350 -84.451700
# 1  42.600090 -82.859990
# 2  42.391150 -83.060470
# 3  42.391151 -83.060471
# 4  44.298230 -84.682130

# %% [markdown]
# ## Pleasantrees Dispensary Locations

# %% [markdown]
# Website | #30DayMapChallenge 2023, Day 1: Points

# %%
tiles = "cartodb positron"
m = folium.Map(tiles=tiles,
# 'https://tile.thunderforest.com/mobile-atlas/{z}/{x}/{y}.png?apikey=c2d093a0cb4743f3869a1d2e5a814b02',
attr="Thunderforest",
location=[42.331429, -83.045753], zoom_start=7)



folium.Marker(
    location=[42.60009, -82.85999],
    tooltip="Pleasantrees - Mt. Clemens",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[42.256360, -83.182860],
    tooltip="Pleasantrees - Lincoln Park",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[42.39115, -83.06047],
    tooltip="Pleasantrees - Hamtramck",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[42.74735, -84.4517],
    tooltip="Pleasantrees - East Lansing",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[44.29823, -84.68213],
    tooltip="Pleasantrees - Houghton Lake",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=da45a442-1bdb-4b3b-93e5-844a336c9733' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
